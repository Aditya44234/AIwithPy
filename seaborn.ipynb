# %% [markdown]
# # SEABORN FOR ADVANCED DATA VISUALISATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=sns.load_dataset("titanic")
df.head()
plt.figure(figsize=(4,3))
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='sex',data=df,hue="survived",width=0.5)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # KDE PLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=sns.load_dataset("titanic")

sns.kdeplot(x= "pclass",data=df,color='red',fill=True)
# Out:
# <Axes: xlabel='pclass', ylabel='Density'>

# %%
sns.displot(x='age',kde=True,bins=5,data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.get_dataset_names()
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
sns.countplot(x='sex',data=df,width=0.3,hue="survived",palette="Set1")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# KDE plot

sns.kdeplot(x='age',data=df,fill=True,color='purple')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
# DISTRIBUTION PLOT
sns.displot(x='age',data=df,kde=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# sns.displot(x='age',data=df,bins=5,kde=True,hue=df['survived'],palette="Set3")
# KDE plot
rich = pd.read_csv(r"C:\Users\ADITYA JOSHI\.idea\Downloads\archive\forbes_richman.csv",encoding="ISO-8859-1")
rich.head(10)
# Out:
#    Rank                      Name Net Worth   Age        Country  \
# 0   1.0                 Elon Musk    $219 B  50.0  United States
# 1   2.0                Jeff Bezos    $171 B  58.0  United States
# 2   3.0  Bernard Arnault & family    $158 B  73.0         France
# 3   4.0                Bill Gates    $129 B  66.0  United States
# 4   5.0            Warren Buffett    $118 B  91.0  United States
# 5   6.0                Larry Page    $111 B  49.0  United States
# 6   7.0               Sergey Brin    $107 B  48.0  United States
# 7   8.0             Larry Ellison    $106 B  77.0  United States
# 8   9.0             Steve Ballmer   $91.4 B  66.0  United States
# 9  10.0             Mukesh Ambani   $90.7 B  64.0          India
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# ...

# %%
sns.kdeplot(x='Age',data=rich.head(12),fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(x='Age',data=rich.head(5),hue=rich['Age'].head(5),kde=True,bins=5)

# %% [markdown]
# # SCATTER PLOT

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
 
df=sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x="sepal_length",data=df,y="petal_length",hue="species",style="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x="sepal_width",data=df,y="petal_width",hue="species",style="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # JOINT PLOT

# %%
sns.jointplot(x="sepal_length",data=df,y="petal_length",hue="species")

# %%
sns.jointplot(x="sepal_length",data=df,y="petal_length",kind="kde")

# %%
sns.jointplot(x="sepal_length",data=df,y="petal_length",kind="reg")

# %% [markdown]
# # PAIR PLOT

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)

# %% [markdown]
# # HEAT MAP

# %%
df2=sns.load_dataset("penguins")
corr=df2.corr()
sns.heatmap(corr,annot=True,cmap="coolwarm",linewidths=0.5)
